# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from datetime import datetime

# %%
df = pd.read_csv(r'C:\Users\King\Desktop\NFLX.csv')

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1     2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2     2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3     2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4     2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...          ...         ...         ...         ...         ...         ...
# 1004  2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005  2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006  2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007  2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008  2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#         Volume
# 0     11896100
# ...

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1009.000000  1009.000000  1009.000000  1009.000000  1009.000000
# mean    419.059673   425.320703   412.374044   419.000733   419.000733
# std     108.537532   109.262960   107.555867   108.289999   108.289999
# min     233.919998   250.649994   231.229996   233.880005   233.880005
# 25%     331.489990   336.299988   326.000000   331.619995   331.619995
# 50%     377.769989   383.010010   370.880005   378.670013   378.670013
# 75%     509.130005   515.630005   502.529999   509.079987   509.079987
# max     692.349976   700.989990   686.090027   691.690002   691.690002
#
#              Volume
# count  1.009000e+03
# mean   7.570685e+06
# std    5.465535e+06
# min    1.144000e+06
# 25%    4.091900e+06
# 50%    5.934500e+06
# 75%    9.322400e+06
# max    5.890430e+07

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1  2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2  2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3  2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4  2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900

# %%
# Set the default figure size
sns.set(rc={'figure.figsize': (10, 5)})

# %%
# Convert 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Set 'Date' as the DataFrame index
df = df.set_index('Date')

# Display the DataFrame
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#               Volume
# Date
# 2018-02-05  11896100
# 2018-02-06  12595800
# 2018-02-07   8981500
# 2018-02-08   9306700
# 2018-02-09  16906900

# %%
# Create the line plot
sns.lineplot(x=df.index, y=df['Volume'], label='Volume', color='blue')

# Add title and labels
plt.title('Volume of Stock Over Time')
plt.xlabel('Date')
plt.ylabel('Volume')

# Add a legend
plt.legend()

# Improve layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# C:\Users\King\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\King\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[115], line 5
#       2 sns.lineplot(x=df.index, y=df['Volume'], label='Volume', color='blue')
#       4 # Add title and labels
# ----> 5 plt.title('Volume of Stock Over Time')
#       6 plt.xlabel('Date')
#       7 plt.ylabel('Volume')
#
# TypeError: 'str' object is not callable

# %%
# Plot the DataFrame
ax = df.plot(y=['High', 'Close', 'Open'], figsize=(10, 5), title='Netflix Stock Price')

# Add title and labels
plt.xlabel('Date')
plt.ylabel('Price')

# Improve layout
    plt.tight_layout()

# Show the plot
plt.show()

# %%
# Create subplots
fig, (ax1, ax2, ax3) = plt.subplots(3, figsize=(15, 10))

# Plot average 'Volume' by day of the month
df.groupby(df.index.day).mean().plot(y='Volume', ax=ax1, color='blue')
ax1.set_title('Average Volume by Day of the Month')
ax1.set_xlabel('Day')
ax1.set_ylabel('Average Volume')

# Plot average 'Volume' by month
df.groupby(df.index.month).mean().plot(y='Volume', ax=ax2, color='green')
ax2.set_title('Average Volume by Month')
ax2.set_xlabel('Month')
ax2.set_ylabel('Average Volume')

# Plot average 'Volume' by year
df.groupby(df.index.year).mean().plot(y='Volume', ax=ax3, color='red')
ax3.set_title('Average Volume by Year')
ax3.set_xlabel('Year')
ax3.set_ylabel('Average Volume')

# Improve layout to avoid overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
a = df.sort_values(by = 'High', ascending = False).head(5)
a['High']
# Out:
# Date
# 2021-11-17    700.989990
# 2021-11-19    694.159973
# 2021-11-18    691.739990
# 2021-10-29    690.969971
# 2021-11-01    689.969971
# Name: High, dtype: float64

# %%
a = df.sort_values(by = 'Low', ascending = True).head(5)
a['Low']
# Out:
# Date
# 2018-12-26    231.229996
# 2018-12-24    233.679993
# 2018-02-09    236.110001
# 2018-12-27    240.100006
# 2018-12-21    241.289993
# Name: Low, dtype: float64

# %%
# Create subplots with shared x-axis
fig, axes = plt.subplots(nrows=1, ncols=2, sharex=True, figsize=(12, 5))

# Set the figure title
fig.suptitle('High & Low Values of Stock Over Time', fontsize=18)

# Plot 'High' values
sns.lineplot(ax=axes[0], x=df.index, y=df['High'], color='green')
axes[0].set_title('High Values')
axes[0].set_xlabel('Date')
axes[0].set_ylabel('Price')

# Plot 'Low' values
sns.lineplot(ax=axes[1], x=df.index, y=df['Low'], color='red')
axes[1].set_title('Low Values')
axes[1].set_xlabel('Date')
axes[1].set_ylabel('Price')

# Improve layout and show the plot
plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjust layout to make room for suptitle
plt.show()
# Out:
# C:\Users\King\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\King\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\King\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
